# %% [markdown]
# # Prac 08.1
#
# In this homework you are going to build your first classifier for the CIFAR-10 dataset. This dataset contains 10 different classes and you can learn more about it [here](https://www.cs.toronto.edu/~kriz/cifar.html). This homework consists of the following tasks:
# * Dataset inspection
# * Building the network
# * Training
# * Evaluation
#
# At the end, as usual, there will be a couple of questions for you to answer :-)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D, Dropout
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
import random
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Step 0: Dataset Inspection
#
# Load the dataset and make a quick inspection.

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
# Mapping from class ID to class name
classes = {0:'plane', 1:'car', 2:'bird', 3:'cat', 4:'deer',
           5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# Dataset params
num_classes = len(classes)
size = x_train.shape[1]

# Visualize random samples (as a plot with 3x6 samples)
for ii in range(18):    
    plt.subplot(3,6,ii+1)
    # Pick a random sample
    idx = random.randint(0,x_train.shape[0])
    # Show the image and the label
    plt.imshow(x_train[idx, ...])
    plt.title(classes[int(y_train[idx])])

# %% [markdown]
# Compute the class histogram (you can visualize it if you want). Is the dataset balanced?
#
# Hint: You might find [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) tool useful. In any case, it's up to you how you compute the histogram.

# %%
class_histogram=np.histogram(y_train, bins=np.arange(11))[0]
plt.bar(classes.values(), class_histogram, color='skyblue')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Step 1: Data Preparation
#
# In this step, you'll need to prepare the data for training, i.e., you will have to normalize it and encode the labels as one-hot vectors.

# %%
from sklearn.preprocessing import OneHotEncoder
# Normalization
x_train = x_train/255
x_test = x_test/255

# One-hot encoding
encoder = OneHotEncoder(categories='auto', sparse=False)

y_train = encoder.fit_transform(y_train)
y_test = encoder.fit_transform(y_test)

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    50000 samples
# Test set:     10000 samples
# Sample dims:  (50000, 32, 32, 3)

# %% [markdown]
# ### Step 2: Building the Classifier
#
# Build the CNN for CIFAR10 classification. For starters, you can use the same network we used in the lesson for the MNIST problem.

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# Build the classifier
inputs = Input(shape=(32, 32, 3))

net = Conv2D(32, kernel_size=(3, 3), activation="relu")(inputs)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)
net = Conv2D(64, kernel_size=(3, 3), activation="relu")(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)
net = Conv2D(128, kernel_size=(3, 3), activation="relu")(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)
net = Flatten()(net)
net= Dense(64, activation='relu')(net)
outputs = Dense(num_classes, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 64)                32832
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 126730 (495.04 KB)
# Trainable params: 126730 (495.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 3: Training
#
# Compile the model and train it.

# %%
epochs = 50
batch_size = 128

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
# Train the model
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.25)
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 293/293 [==============================] - 10s 30ms/step - loss: 1.8230 - accuracy: 0.3213 - val_loss: 1.5948 - val_accuracy: 0.4164
# Epoch 2/50
# 293/293 [==============================] - 8s 29ms/step - loss: 1.4723 - accuracy: 0.4594 - val_loss: 1.3592 - val_accuracy: 0.5171
# Epoch 3/50
# 293/293 [==============================] - 8s 29ms/step - loss: 1.3296 - accuracy: 0.5159 - val_loss: 1.2545 - val_accuracy: 0.5614
# Epoch 4/50
# 293/293 [==============================] - 8s 29ms/step - loss: 1.2364 - accuracy: 0.5564 - val_loss: 1.1597 - val_accuracy: 0.5900
# Epoch 5/50
# 293/293 [==============================] - 8s 29ms/step - loss: 1.1767 - accuracy: 0.5789 - val_loss: 1.1162 - val_accuracy: 0.6019
# Epoch 6/50
# 293/293 [==============================] - 8s 28ms/step - loss: 1.1217 - accuracy: 0.6039 - val_loss: 1.0349 - val_accuracy: 0.6366
# Epoch 7/50
# 293/293 [==============================] - 8s 29ms/step - loss: 1.0693 - accuracy: 0.6213 - val_loss: 1.0024 - val_accuracy: 0.6562
# Epoch 8/50
# 293/293 [==============================] - 8s 29ms/step - loss: 1.0389 - accuracy: 0.6353 - val_loss: 0.9669 - val_accuracy: 0.6652
# Epoch 9/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.9947 - accuracy: 0.6498 - val_loss: 0.9594 - val_accuracy: 0.6667
# Epoch 10/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.9653 - accuracy: 0.6595 - val_loss: 0.9281 - val_accuracy: 0.6813
# Epoch 11/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.9379 - accuracy: 0.6699 - val_loss: 0.9011 - val_accuracy: 0.6880
# Epoch 12/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.9149 - accuracy: 0.6781 - val_loss: 0.8607 - val_accuracy: 0.7031
# Epoch 13/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.8913 - accuracy: 0.6862 - val_loss: 0.8489 - val_accuracy: 0.7088
# Epoch 14/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.8707 - accuracy: 0.6946 - val_loss: 0.8337 - val_accuracy: 0.7110
# Epoch 15/50
# 293/293 [==============================] - 9s 29ms/step - loss: 0.8490 - accuracy: 0.7034 - val_loss: 0.8209 - val_accuracy: 0.7187
# Epoch 16/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.8289 - accuracy: 0.7079 - val_loss: 0.8285 - val_accuracy: 0.7113
# Epoch 17/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.8241 - accuracy: 0.7116 - val_loss: 0.8190 - val_accuracy: 0.7174
# Epoch 18/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.8079 - accuracy: 0.7141 - val_loss: 0.7747 - val_accuracy: 0.7370
# Epoch 19/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.7925 - accuracy: 0.7218 - val_loss: 0.7796 - val_accuracy: 0.7338
# Epoch 20/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.7776 - accuracy: 0.7259 - val_loss: 0.7691 - val_accuracy: 0.7341
# Epoch 21/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.7646 - accuracy: 0.7298 - val_loss: 0.7641 - val_accuracy: 0.7366
# Epoch 22/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.7540 - accuracy: 0.7361 - val_loss: 0.7610 - val_accuracy: 0.7385
# Epoch 23/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.7516 - accuracy: 0.7363 - val_loss: 0.7695 - val_accuracy: 0.7359
# Epoch 24/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.7324 - accuracy: 0.7429 - val_loss: 0.7448 - val_accuracy: 0.7434
# Epoch 25/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.7198 - accuracy: 0.7467 - val_loss: 0.7371 - val_accuracy: 0.7474
# Epoch 26/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.7202 - accuracy: 0.7446 - val_loss: 0.7437 - val_accuracy: 0.7460
# Epoch 27/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.7087 - accuracy: 0.7486 - val_loss: 0.7400 - val_accuracy: 0.7452
# Epoch 28/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.7065 - accuracy: 0.7515 - val_loss: 0.7212 - val_accuracy: 0.7512
# Epoch 29/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6965 - accuracy: 0.7547 - val_loss: 0.7235 - val_accuracy: 0.7519
# Epoch 30/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6924 - accuracy: 0.7540 - val_loss: 0.7305 - val_accuracy: 0.7486
# Epoch 31/50
# 293/293 [==============================] - 9s 30ms/step - loss: 0.6752 - accuracy: 0.7626 - val_loss: 0.7162 - val_accuracy: 0.7533
# Epoch 32/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6766 - accuracy: 0.7590 - val_loss: 0.7112 - val_accuracy: 0.7544
# Epoch 33/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6667 - accuracy: 0.7658 - val_loss: 0.7157 - val_accuracy: 0.7596
# Epoch 34/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6608 - accuracy: 0.7666 - val_loss: 0.7014 - val_accuracy: 0.7592
# Epoch 35/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6618 - accuracy: 0.7668 - val_loss: 0.7219 - val_accuracy: 0.7547
# Epoch 36/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6535 - accuracy: 0.7684 - val_loss: 0.6898 - val_accuracy: 0.7652
# Epoch 37/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6408 - accuracy: 0.7734 - val_loss: 0.7076 - val_accuracy: 0.7600
# Epoch 38/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6417 - accuracy: 0.7750 - val_loss: 0.7120 - val_accuracy: 0.7570
# Epoch 39/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6389 - accuracy: 0.7745 - val_loss: 0.6875 - val_accuracy: 0.7662
# Epoch 40/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6291 - accuracy: 0.7792 - val_loss: 0.7064 - val_accuracy: 0.7580
# Epoch 41/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6225 - accuracy: 0.7802 - val_loss: 0.7010 - val_accuracy: 0.7574
# Epoch 42/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6250 - accuracy: 0.7772 - val_loss: 0.7020 - val_accuracy: 0.7577
# Epoch 43/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6218 - accuracy: 0.7811 - val_loss: 0.6992 - val_accuracy: 0.7602
# Epoch 44/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6197 - accuracy: 0.7801 - val_loss: 0.7008 - val_accuracy: 0.7592
# Epoch 45/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6076 - accuracy: 0.7837 - val_loss: 0.6939 - val_accuracy: 0.7621
# Epoch 46/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6033 - accuracy: 0.7882 - val_loss: 0.6965 - val_accuracy: 0.7602
# Epoch 47/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6013 - accuracy: 0.7868 - val_loss: 0.6839 - val_accuracy: 0.7636
# Epoch 48/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.6037 - accuracy: 0.7862 - val_loss: 0.6874 - val_accuracy: 0.7644
# Epoch 49/50
# 293/293 [==============================] - 8s 28ms/step - loss: 0.5987 - accuracy: 0.7864 - val_loss: 0.7003 - val_accuracy: 0.7581
# Epoch 50/50
# 293/293 [==============================] - 8s 29ms/step - loss: 0.6002 - accuracy: 0.7848 - val_loss: 0.6678 - val_accuracy: 0.7728

# %%
# Show training history (this cell is complete, nothing to implement here :-) )
h = history.history
epochs = range(len(h['loss']))

plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
plt.legend(['Train', 'Validation'])
plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                           epochs, h['val_accuracy'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

print('Train Acc     ', h['accuracy'][-1])
print('Validation Acc', h['val_accuracy'][-1])
# Out:
# Train Acc      0.7847999930381775
# Validation Acc 0.7728000283241272

# %% [markdown]
# ### Step 4: Evaluation
#
# In this step, you have to calculate the accuracies and visualize some random samples. For the evaluation, you are going to use the test split from the dataset.

# %%
# Compute the labels and the predictions as sparse values
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred=y_pred.argmax(axis=1)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
# Compute and print the accuracy for each class
from sklearn.metrics import accuracy_score

for class_id, class_name in classes.items():
    mask = y_true==class_id
    
    acc = accuracy_score(y_true[mask],y_pred[mask])
    print(class_name, acc)
# Out:
# plane 0.82
# car 0.867
# bird 0.666
# cat 0.556
# deer 0.717
# dog 0.611
# frog 0.873
# horse 0.831
# ship 0.857
# truck 0.853

# %%
# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6846 - accuracy: 0.7651
# Test loss   0.6845601201057434
# Test metric 0.7651000022888184

# %%
# Show random samples
for ii in range(15):
    # Pick a random sample
    idx = random.randint(0,x_test.shape[0])
    # Show the results
    plt.subplot(3,5,ii+1), plt.imshow(x_test[idx, ...])
    plt.title('True: ' + str(classes[y_true[idx]]) + ' | Pred: ' + str(classes[y_pred[idx]]))

# %% [markdown]
# ### Questions
# * What is the overall accuracy of the classifier?
# * What modifications would you do in order to improve the classification accuracy?
# * Make **one** modification (that you think can help) and train the classifier again. Does the accuracy improve?
