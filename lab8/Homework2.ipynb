# %% [markdown]
# # Prac 08.2
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3213002 (12.26 MB)
# Trainable params: 3213002 (12.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 3
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/3
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 938/938 [==============================] - 30s 31ms/step - loss: 0.3968 - accuracy: 0.8632 - val_loss: 0.3307 - val_accuracy: 0.8835
# Epoch 2/3
# 938/938 [==============================] - 29s 31ms/step - loss: 0.2683 - accuracy: 0.9043 - val_loss: 0.2966 - val_accuracy: 0.8942
# Epoch 3/3
# 938/938 [==============================] - 28s 30ms/step - loss: 0.2302 - accuracy: 0.9167 - val_loss: 0.3005 - val_accuracy: 0.8937

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9166833162307739
# Validation Acc 0.8937000036239624

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
# net = MaxPooling2D(pool_size=(2, 2))(net)
net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = MaxPooling2D(pool_size=(3, 3))(net)
net = Flatten()(net)

net = Dense(64)(net) #, kernel_regularizer=regularizers.l2(0.001)
net = Dropout(0.7)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\koles\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 9, 9, 64)          0
#  D)
#
#  flatten_1 (Flatten)         (None, 5184)              0
#
#  dense_2 (Dense)             (None, 64)                331840
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 333130 (1.27 MB)
# Trainable params: 333130 (1.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the network
epochs = 100
batch_size = 64

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test) ,callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 938/938 [==============================] - 11s 11ms/step - loss: 0.5654 - accuracy: 0.8085 - val_loss: 0.3624 - val_accuracy: 0.8727
# Epoch 2/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.3959 - accuracy: 0.8672 - val_loss: 0.3146 - val_accuracy: 0.8858
# Epoch 3/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.3552 - accuracy: 0.8784 - val_loss: 0.3032 - val_accuracy: 0.8936
# Epoch 4/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.3333 - accuracy: 0.8869 - val_loss: 0.2878 - val_accuracy: 0.8994
# Epoch 5/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.3150 - accuracy: 0.8939 - val_loss: 0.2873 - val_accuracy: 0.8988
# Epoch 6/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.3034 - accuracy: 0.8967 - val_loss: 0.2713 - val_accuracy: 0.9019
# Epoch 7/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2896 - accuracy: 0.9008 - val_loss: 0.2695 - val_accuracy: 0.9046
# Epoch 8/100
# 938/938 [==============================] - 11s 11ms/step - loss: 0.2795 - accuracy: 0.9043 - val_loss: 0.2708 - val_accuracy: 0.9048
# Epoch 9/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2719 - accuracy: 0.9067 - val_loss: 0.2592 - val_accuracy: 0.9080
# Epoch 10/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2624 - accuracy: 0.9104 - val_loss: 0.2625 - val_accuracy: 0.9078
# Epoch 11/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2571 - accuracy: 0.9119 - val_loss: 0.2618 - val_accuracy: 0.9089
# Epoch 12/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2511 - accuracy: 0.9128 - val_loss: 0.2688 - val_accuracy: 0.9066
# Epoch 13/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2430 - accuracy: 0.9151 - val_loss: 0.2577 - val_accuracy: 0.9099
# Epoch 14/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2371 - accuracy: 0.9174 - val_loss: 0.2614 - val_accuracy: 0.9096
# Epoch 15/100
# 938/938 [==============================] - 11s 12ms/step - loss: 0.2336 - accuracy: 0.9199 - val_loss: 0.2712 - val_accuracy: 0.9067
# Epoch 16/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2273 - accuracy: 0.9196 - val_loss: 0.2650 - val_accuracy: 0.9090
# Epoch 17/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2208 - accuracy: 0.9225 - val_loss: 0.2616 - val_accuracy: 0.9114
# Epoch 18/100
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2215 - accuracy: 0.9229 - val_loss: 0.2615 - val_accuracy: 0.9114

# %%
# Show the results
plot_history(history)
# Out:
# Train Acc      0.9228500127792358
# Validation Acc 0.9114000201225281

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
# * Have you tried configurations that did not work out?
